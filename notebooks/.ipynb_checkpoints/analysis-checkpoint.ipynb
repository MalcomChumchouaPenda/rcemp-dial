# %%
from tools import rendering as vw

# %%
ganttview = vw.GanttView('BencheikhAl2022')
ganttview

# %%
f = lambda exp: f"{exp['problem_name']} {exp['model_name'][:-5]}"
ganttview.plot('k1_10__', '%CEMPM%', title_format=f)

# %%
f = lambda exp: f"{exp['problem_name'][:-2].replace('_', '-')} ({exp['model_name'][:-5]})"
f = lambda exp: '(a)' if exp['model_name'][:-5] == 'SCEMP' else '(b)'
ganttview.plot('k1_10_3', '%CEMPM%', title_format=f, time_window=(0, 1200), saveas='gantt_comparison.png')

# %%
prod_var_names = ['Cmax', 'R', 'nR']
statsview = vw.StatsView('BencheikhAl2022')
statsview.compare('RCEMPModel', 'SCEMPModel', prod_var_names, 
                  instance_pattern='(\S+)_\d+', by_method=True,
                  save_as='prod_performances.csv')
# Out:
# model_name RCEMPModel                     SCEMPModel
# var_name         Cmax          R     nR         Cmax            R      nR
# k1_10         700.000    2652.60   8.30    1230.4000     7246.400   9.400
# k1_100       3610.050  173810.90  98.30   60628.1000  5613294.000  99.200
# k1_20         918.550    7995.35  18.80    3412.4500    52620.300  19.200
# k1_30        1220.700   15762.65  28.70    7048.1000   175133.900  28.900
# k1_40        1460.250   27633.15  38.60   11050.5500   382388.200  39.100
# k1_50        2025.350   43387.70  48.80   17176.0000   769000.200  49.400
# k1_60        2405.450   63241.85  58.70   24721.5500  1350957.000  59.800
# k1_70        2512.550   84294.20  68.40   31994.2500  2049295.000  69.400
# k1_80        2956.350  108200.10  79.10   41469.2500  3049532.000  79.500
# k1_90        3410.500  131196.00  88.20   48927.7000  4026019.000  89.200
# k2_10         412.050    1542.70   8.50    1721.7000    11949.400   9.100
# k2_100       3282.850  152315.00  98.60  114399.5000  9286591.000  98.900
# k2_20         644.450    5571.90  19.10    6126.7000    99806.500  19.400
# k2_30         991.200   13644.75  28.90   15104.7000   381380.600  29.300
# k2_40        1280.000   24520.55  38.60   23400.5000   802411.400  39.600
# k2_50        1648.950   36574.75  49.00   36994.3000  1560259.000  49.400
# k2_60        1788.950   51314.80  58.40   47904.2000  2434536.000  59.500
# k2_70        2451.750   74790.35  68.80   63448.1000  3708173.000  69.400
# k2_80        2655.850  100128.00  78.90   78685.0000  5188277.000  79.300
# k2_90        3065.100  116590.90  89.10   96501.4000  7002729.000  89.300
# average      1972.045   61758.41  53.69   36597.2225  2397579.945  54.315

# %%
maint_var_names = ['nTM', 'Abar']
statsview.compare('RCEMPModel', 'SCEMPModel', maint_var_names, 
                  instance_pattern='(\S+)_\d+', by_method=True,
                  save_as='maint_performances.csv')
# Out:
# model_name    RCEMPModel            SCEMPModel
# var_name            Abar     nTM          Abar     nTM
# k1_10       0.000000e+00   6.400  0.000000e+00    9.90
# k1_100      2.000000e-01  95.000  2.112450e-07  253.00
# k1_20       1.793360e-19  17.100  3.630810e-38   29.00
# k1_30       5.607780e-22  26.700  4.843630e-23   47.50
# k1_40       2.578704e-03  35.700  1.514820e-24   70.30
# k1_50       9.772500e-02  46.100  2.052260e-11   95.00
# k1_60       1.900560e-01  58.500  4.809630e-06  123.00
# k1_70       8.643340e-02  67.300  2.209050e-08  145.80
# k1_80       9.981340e-02  74.800  4.594630e-16  184.40
# k1_90       3.000000e-01  86.600  2.871660e-03  222.30
# k2_10       0.000000e+00   7.200  0.000000e+00   17.40
# k2_100      4.999936e-01  97.800  3.010630e-14  431.90
# k2_20       6.296320e-26  16.700  0.000000e+00   45.90
# k2_30       1.446610e-10  27.100  2.460910e-36   80.10
# k2_40       1.588870e-04  38.400  6.622580e-25  120.90
# k2_50       1.013778e-01  46.500  3.180659e-23  155.90
# k2_60       1.038969e-01  53.800  1.102560e-28  204.40
# k2_70       2.000000e-01  71.700  1.633780e-25  264.80
# k2_80       2.000000e-01  80.800  1.511177e-24  318.30
# k2_90       2.011750e-01  89.500  7.556570e-25  365.40
# average     1.141604e-01  52.185  1.438351e-04  159.26

# %%
exec_var_names = ['nC', 'Es']
statsview.compare('RCEMPModel', 'SCEMPModel', exec_var_names, 
                  instance_pattern='(\S+)_\d+', by_method=True,
                  save_as='exec_performances.csv')
# Out:
# model_name   RCEMPModel          SCEMPModel
# var_name             Es     nC           Es      nC
# k1_10         33.685040  3.100    49.162590   5.900
# k1_100      1301.168200  3.900  2294.794000  28.100
# k1_20         89.640810  3.500   138.320750   9.000
# k1_30        167.302300  3.500   262.394100  11.300
# k1_40        205.488600  3.500   365.017800  13.400
# k1_50        467.943600  3.700   648.711100  16.000
# k1_60        483.481400  3.900   825.366800  19.100
# k1_70        599.621500  4.100   886.733000  20.700
# k1_80        567.744200  4.200  1225.654100  23.600
# k1_90        750.401600  4.000  1556.734700  26.000
# k2_10         68.403210  3.400    95.394720  11.600
# k2_100      1665.326000  4.200  3049.508000  76.300
# k2_20        138.047820  3.500   227.434500  18.600
# k2_30        225.687000  3.700   403.728800  26.400
# k2_40        302.974700  4.100   564.250900  33.400
# k2_50        600.096400  3.700  1086.076700  40.300
# k2_60        608.626300  3.700  1270.827500  46.900
# k2_70        817.319900  4.500  1547.109000  54.600
# k2_80        661.429100  4.300  1744.206000  61.600
# k2_90        837.544100  4.200  2075.183000  68.900
# average      529.596589  3.835  1015.830403  30.585

# %%
var_names = prod_var_names + maint_var_names + exec_var_names
statsview.test(var_names, problem_filter='%', save_as='test_performances.csv')
# Out:
#   var_name  stat_val       p_value
# 0     Abar      64.0  4.757468e-08
# 1     Cmax       0.0  1.436146e-34
# 2       Es       1.0  1.457939e-34
# 3        R       0.0  1.436146e-34
# 4       nC       0.0  1.410839e-34
# 5       nR       0.0  9.441972e-18
# 6      nTM       4.5  3.262862e-34
