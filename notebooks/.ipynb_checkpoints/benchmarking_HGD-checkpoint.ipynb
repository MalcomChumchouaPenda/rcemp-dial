# %%
# change directory
import os
rootdir = os.path.dirname(os.getcwd())
os.chdir(rootdir)

# import third libs for data
from datetime import datetime as dt
from datetime import timedelta as td
import numpy as np
import pandas as pd

# import config
from config import DATA_DIR

# %% [markdown]
# # Chargement des donnees

# %%
benchmarkname = 'HGD_dialysis_2018_2021'
benchmarkdir = os.path.join(DATA_DIR, 'raw', benchmarkname)
benchmarkdir
# Out:
# 'D:\\Recherches\\Travaux\\RCEMP\\rcemp-dial\\data\\raw\\HGD_dialysis_2018_2021'

# %% [markdown]
# ## chargement des seances

# %%
datapath = os.path.join(benchmarkdir, 'donnees_seances.csv')
seances = pd.read_csv(datapath, sep=';', index_col='Date', parse_dates=True, dayfirst=True)
seances.head()
# Out:
#             ID   Tour  Patients  Debut  Duree
# Date
# 2018-03-26   1  Tour1        21      5      5
# 2018-03-26   2  Tour2        21     10      5
# 2018-03-26   3  Tour3        21     15      5
# 2018-03-26   4  Tour4         8     20      5
# 2018-03-27   5  Tour1        21      5      5

# %%
seances.dtypes
# Out:
# ID           int64
# Tour        object
# Patients     int64
# Debut        int64
# Duree        int64
# dtype: object

# %% [markdown]
# ## chargement des generateurs

# %%
datapath = os.path.join(benchmarkdir, 'donnees_generateurs.csv')
generateurs = pd.read_csv(datapath, sep=';', index_col='Numero')
generateurs.head()
# Out:
#             Code     TT     TO  TNR     TR       TAP        TF    TE     TN  \
# Numero
# 1       7SXAWU98  30576  22932  932  22000   6301.08  15698.92  4.92  15694
# 2       7SXAWT97  30576  22932  932  22000  19262.22   2737.78  1.78   2736
# 3       7SXAWU81  30576  22932  932  22000   9462.73  12537.27  1.27  12536
# 4       7SXAWU91  30576  22932  932  22000   7857.71  14142.29  2.29  14140
# 5       7SXAWS81  30576  22932  932  22000   5639.52  16360.48  4.48  16356
#
#            TU  TRE  TRSi
# Numero
# 1       15694    0   NaN
# 2        2736    0   NaN
# 3       12536    0   NaN
# 4       14140    0   NaN
# 5       16356    0   NaN

# %%
generateurs.dtypes
# Out:
# Code     object
# TT        int64
# TO        int64
# TNR       int64
# TR        int64
# TAP     float64
# TF      float64
# TE      float64
# TN        int64
# TU        int64
# TRE       int64
# TRSi    float64
# dtype: object

# %%
generateurs.Code.sort_values()
# Out:
# Numero
# 24    6SX4LV10
# 21    7SXAWS80
# 5     7SXAWS81
# 20    7SXAWS82
# 2     7SXAWT97
# 8     7SXAWT98
# 14    7SXAWU79
# 17    7SXAWU80
# 3     7SXAWU81
# 12    7SXAWU82
# 22    7SXAWU83
# 18    7SXAWU84
# 19    7SXAWU85
# 9     7SXAWU86
# 7     7SXAWU87
# 11    7SXAWU89
# 16    7SXAWU90
# 4     7SXAWU91
# 15    7SXAWU93
# 13    7SXAWU94
# 23    7SXAWU95
# 6     7SXAWU96
# 10    7SXAWU97
# 1     7SXAWU98
# Name: Code, dtype: object

# %% [markdown]
# ## chargements de l'historique des pannes

# %%
datapath = os.path.join(benchmarkdir, 'donnees_pannes.csv')
pannes = pd.read_csv(datapath, sep=';', index_col='Machines')
pannes = pannes.transpose()
pannes.index = pd.to_datetime(pannes.index, format='%d/%m/%Y')
pannes.fillna(0, inplace=True)
pannes = pannes.astype('Int64')
pannes.head()
# Out:
# Machines    7SXAWU98  7SXAWT97  7SXAWU81  7SXAWU90  7SXAWS81  7SXAWU96  \
# 2020-01-01         0         0         0         0         0         0
# 2020-01-02         0         0         0         0         0         0
# 2020-01-03         0         0         0         0         0         0
# 2020-01-04         0         0         0         0         0         0
# 2020-01-05         0         0         0         0         0         0
#
# Machines    7SXAWU87  7SXAWT98  7SXAWU86  7SXAWU97  ...  7SXAWU93  7SXAWU91  \
# 2020-01-01         0         0         0         0  ...         0         0
# 2020-01-02         0         0         0         0  ...         0         0
# 2020-01-03         0         0         0         0  ...         0         0
# 2020-01-04         0         0         0         0  ...         0         0
# 2020-01-05         0         0         0         0  ...         0         0
#
# Machines    7SXAWU80  7SXAWU84  7SXAWU85  7SXAWS82  7SXAWS80  7SXAWU83  \
# 2020-01-01         0         0         0         0         0         0
# 2020-01-02         0         0         0         0         0         0
# 2020-01-03         0         0         0         0         0         0
# 2020-01-04         0         0         0         0         0         0
# 2020-01-05         0         0         0         0         0         0
#
# Machines    7SXAWU95  6SX4LV10
# 2020-01-01         0         0
# 2020-01-02         0         0
# 2020-01-03         0         0
# 2020-01-04         0         0
# 2020-01-05         0         0
#
# [5 rows x 24 columns]

# %%
pannes.sum()
# Out:
# Machines
# 7SXAWU98     0
# 7SXAWT97     0
# 7SXAWU81    12
# 7SXAWU90     6
# 7SXAWS81    15
# 7SXAWU96    12
# 7SXAWU87     6
# 7SXAWT98     6
# 7SXAWU86     0
# 7SXAWU97    18
# 7SXAWU89     3
# 7SXAWU82     3
# 7SXAWU94    12
# 7SXAWU79     9
# 7SXAWU93     3
# 7SXAWU91    12
# 7SXAWU80    18
# 7SXAWU84     6
# 7SXAWU85     6
# 7SXAWS82     6
# 7SXAWS80     9
# 7SXAWU83     9
# 7SXAWU95    12
# 6SX4LV10    12
# dtype: int64

# %% [markdown]
# ## chargement des tranches horaires

# %%
datapath = os.path.join(benchmarkdir, 'tranches_maintenances.csv')
tranches_maintenances = pd.read_csv(datapath)
tranches_maintenances.set_index('Period', inplace=True)
tranches_maintenances
# Out:
#               D1       D2       D3       D4       D5       D6  D7
# Period
# 0H-1H         --       --       --       --       --       --  --
# 1H-2H         --       --       --       --       --       --  --
# 2H-3H         --       --       --       --       --       --  --
# 3H-4H         --       --       --       --       --       --  --
# 4H-5H    service  service  service  service  service  service  --
# 5H-6H    service  service  service  service  service  service  --
# 6H-7H    service  service  service  service  service  service  --
# 7H-8H    service  service  service  service  service  service  --
# 8H-9H    service  service  service  service  service  service  --
# 9H-10H   service  service  service  service  service  service  --
# 10H-11H  service  service  service  service  service  service  --
# 11H-12H  service  service  service  service  service  service  --
# 12H-13H  service  service  service  service  service  service  --
# 13H-14H  service  service  service  service  service  service  --
# 14H-15H  service  service  service  service  service  service  --
# 15H-16H  service  service  service  service  service  service  --
# 16H-17H  service  service  service  service  service  service  --
# 17H-18H  service  service  service  service  service  service  --
# 18H-19H  service  service  service  service  service  service  --
# 19H-20H  service  service  service  service  service  service  --
# 20H-21H  service  service  service  service  service  service  --
# 21H-22H  service  service  service  service  service  service  --
# 22H-23H  service  service  service  service  service  service  --
# 23H-24H  service  service  service  service  service  service  --

# %%
datapath = os.path.join(benchmarkdir, 'tranches_soins.csv')
tranches_soins = pd.read_csv(datapath)
tranches_soins.set_index('Period', inplace=True)
tranches_soins
# Out:
#              D1      D2      D3      D4      D5      D6      D7
# Period
# 0H-1H        --  soins4  soins4  soins4  soins4  soins4  soins4
# 1H-2H        --      --      --      --      --      --      --
# 2H-3H        --      --      --      --      --      --      --
# 3H-4H        --      --      --      --      --      --      --
# 4H-5H        --      --      --      --      --      --      --
# 5H-6H    soins1  soins1  soins1  soins1  soins1  soins1      --
# 6H-7H    soins1  soins1  soins1  soins1  soins1  soins1      --
# 7H-8H    soins1  soins1  soins1  soins1  soins1  soins1      --
# 8H-9H    soins1  soins1  soins1  soins1  soins1  soins1      --
# 9H-10H   soins1  soins1  soins1  soins1  soins1  soins1      --
# 10H-11H  soins2  soins2  soins2  soins2  soins2  soins2      --
# 11H-12H  soins2  soins2  soins2  soins2  soins2  soins2      --
# 12H-13H  soins2  soins2  soins2  soins2  soins2  soins2      --
# 13H-14H  soins2  soins2  soins2  soins2  soins2  soins2      --
# 14H-15H  soins2  soins2  soins2  soins2  soins2  soins2      --
# 15H-16H  soins3  soins3  soins3  soins3  soins3  soins3      --
# 16H-17H  soins3  soins3  soins3  soins3  soins3  soins3      --
# 17H-18H  soins3  soins3  soins3  soins3  soins3  soins3      --
# 18H-19H  soins3  soins3  soins3  soins3  soins3  soins3      --
# 19H-20H  soins3  soins3  soins3  soins3  soins3  soins3      --
# 20H-21H  soins4  soins4  soins4  soins4  soins4  soins4      --
# 21H-22H  soins4  soins4  soins4  soins4  soins4  soins4      --
# 22H-23H  soins4  soins4  soins4  soins4  soins4  soins4      --
# 23H-24H  soins4  soins4  soins4  soins4  soins4  soins4      --

# %% [markdown]
# # Identification de la periode d'echantillonage

# %% [markdown]
# ## periodes de collecte des seances

# %%
debut_seances = seances['Patients'].index.min()
fin_seances = seances['Patients'].index.max()
fin_seances= fin_seances + pd.DateOffset(1)
debut_seances, fin_seances
# Out:
# (Timestamp('2020-01-01 00:00:00'), Timestamp('2021-05-23 00:00:00'))

# %% [markdown]
# ## periodes de collecte des pannes

# %%
debut_pannes = []
fin_pannes = []
for machine in pannes.columns:
    test = pannes[machine]
    periodes = test[test == 1].index
    if len(periodes) == 0:
        continue
    debut_machine = periodes.min()
    debut_pannes.append(debut_machine)
    fin_machine = periodes.max()
    fin_pannes.append(fin_machine)
    print(machine, debut_machine, fin_machine)
debut_pannes = max(debut_pannes)
fin_pannes = max(fin_pannes)
fin_pannes= fin_pannes + pd.DateOffset(1)
debut_pannes, fin_pannes
# Out:
# 7SXAWU81 2020-09-19 00:00:00 2021-06-03 00:00:00
# 7SXAWU90 2020-10-01 00:00:00 2020-10-10 00:00:00
# 7SXAWS81 2020-04-27 00:00:00 2021-06-30 00:00:00
# 7SXAWU96 2020-07-09 00:00:00 2021-05-30 00:00:00
# 7SXAWU87 2020-08-13 00:00:00 2021-04-25 00:00:00
# 7SXAWT98 2020-11-06 00:00:00 2021-05-06 00:00:00
# 7SXAWU97 2020-07-04 00:00:00 2021-02-12 00:00:00
# 7SXAWU89 2020-09-17 00:00:00 2020-09-19 00:00:00
# 7SXAWU82 2020-09-17 00:00:00 2020-09-19 00:00:00
# 7SXAWU94 2020-09-19 00:00:00 2021-12-02 00:00:00
# 7SXAWU79 2020-06-17 00:00:00 2021-05-06 00:00:00
# 7SXAWU93 2020-10-09 00:00:00 2020-10-11 00:00:00
# 7SXAWU91 2020-09-12 00:00:00 2021-06-30 00:00:00
# 7SXAWU80 2020-09-19 00:00:00 2021-05-06 00:00:00
# 7SXAWU84 2020-02-14 00:00:00 2020-07-25 00:00:00
# 7SXAWU85 2020-08-23 00:00:00 2021-06-17 00:00:00
# 7SXAWS82 2020-09-17 00:00:00 2021-04-29 00:00:00
# 7SXAWS80 2020-07-13 00:00:00 2020-12-19 00:00:00
# 7SXAWU83 2020-09-17 00:00:00 2020-12-03 00:00:00
# 7SXAWU95 2020-03-30 00:00:00 2021-03-27 00:00:00
# 6SX4LV10 2020-09-17 00:00:00 2021-06-03 00:00:00
# (Timestamp('2020-11-06 00:00:00'), Timestamp('2021-12-03 00:00:00'))

# %% [markdown]
# # Identification des patients

# %% [markdown]
# ## Regroupement des patients par jour

# %%
seances_by_date = seances.groupby('Date')
seances_sum_by_date = seances_by_date.sum(numeric_only=True)
patients_count = seances_sum_by_date['Patients']
patients = pd.DataFrame(patients_count)
patients.columns = ['number']
patients.head()
# Out:
#             number
# Date
# 2020-01-01      68
# 2020-01-02      71
# 2020-01-03      72
# 2020-01-06      73
# 2020-01-07      72

# %%
patients['day'] = patients_count.index.weekday + 1
patients.head()
# Out:
#             number  day
# Date
# 2020-01-01      68    3
# 2020-01-02      71    4
# 2020-01-03      72    5
# 2020-01-06      73    1
# 2020-01-07      72    2

# %% [markdown]
# ## Calcul des preferences des patients

# %%
seances_by_tour = seances.groupby('Tour')
seances_by_tour_min = seances_by_tour.min()
seances_by_tour_max = seances_by_tour.max()
seances_by_tour_min.head()
patients['release_date'] = seances_by_tour_min.loc['Tour1', 'Debut']
patients['due_date'] = seances_by_tour_max.loc['Tour4', 'Debut']
patients['duration'] = seances_by_tour_min.loc['Tour1', 'Duree']
patients.head()
# Out:
#             number  day  release_date  due_date  duration
# Date
# 2020-01-01      68    3             5        20         5
# 2020-01-02      71    4             5        20         5
# 2020-01-03      72    5             5        20         5
# 2020-01-06      73    1             5        20         5
# 2020-01-07      72    2             5        20         5

# %% [markdown]
# ## Identification des periodes de soins

# %%
patients.reset_index(inplace=True)
patients['period'] = patients['Date'].dt.to_period('W').apply(lambda r: r.end_time.date)
patients['period'] = pd.to_datetime(patients['period'])
patients.set_index('Date', inplace=True)
patients.tail(10)
# Out:
#             number  day  release_date  due_date  duration     period
# Date
# 2021-05-12      70    3             5        20         5 2021-05-16
# 2021-05-13      63    4             5        20         5 2021-05-16
# 2021-05-14      66    5             5        20         5 2021-05-16
# 2021-05-15      63    6             5        20         5 2021-05-16
# 2021-05-17      71    1             5        20         5 2021-05-23
# 2021-05-18      68    2             5        20         5 2021-05-23
# 2021-05-19      65    3             5        20         5 2021-05-23
# 2021-05-20      63    4             5        20         5 2021-05-23
# 2021-05-21      71    5             5        20         5 2021-05-23
# 2021-05-22      60    6             5        20         5 2021-05-23

# %% [markdown]
# # Identification des machines

# %% [markdown]
# ## Identification des machines par defaut

# %%
total_pannes = pannes.sum().astype('Int64')
machines_utiles = total_pannes[total_pannes > 0].index.to_list()
machines_utiles, len(machines_utiles)
# Out:
# (['7SXAWU81',
#   '7SXAWU90',
#   '7SXAWS81',
#   '7SXAWU96',
#   '7SXAWU87',
#   '7SXAWT98',
#   '7SXAWU97',
#   '7SXAWU89',
#   '7SXAWU82',
#   '7SXAWU94',
#   '7SXAWU79',
#   '7SXAWU93',
#   '7SXAWU91',
#   '7SXAWU80',
#   '7SXAWU84',
#   '7SXAWU85',
#   '7SXAWS82',
#   '7SXAWS80',
#   '7SXAWU83',
#   '7SXAWU95',
#   '6SX4LV10'],
#  21)

# %% [markdown]
# ## identification des machines de secours

# %%
machines_secours = total_pannes[total_pannes == 0].index
machines_secours
# Out:
# Index(['7SXAWU98', '7SXAWT97', '7SXAWU86'], dtype='object', name='Machines')

# %%
temps_secours = generateurs.set_index('Code')
temps_secours = temps_secours.loc[machines_secours, 'TF']
temps_secours.sort_values(ascending=False)
# Out:
# Machines
# 7SXAWU98    15698.92
# 7SXAWT97     2737.78
# 7SXAWU86     1705.91
# Name: TF, dtype: float64

# %%
ordre_secours = temps_secours.sort_values(ascending=False).index
ordre_secours = ordre_secours.to_list()
ordre_secours
# Out:
# ['7SXAWU98', '7SXAWT97', '7SXAWU86']

# %% [markdown]
# ## identification des machines utilisees

# %%
use_jours = pd.DataFrame(0, index=pannes.index, columns=pannes.columns)
nb_machines = len(machines_utiles)
for jour in pannes.index:
    test = pannes.loc[jour]
    machines_pannes = test[test == 1].index
    machines_pannes = machines_pannes.to_list()
    if len(machines_pannes) > 0:
        machines_jour= [m for m in machines_utiles if m not in machines_pannes]
        machines_jour.extend(ordre_secours[:nb_machines - len(machines_jour)])
    else:
        machines_jour = list(machines_utiles)
    use_jours.loc[jour, machines_jour] = 1
    # print(jour, len(machines_jour), machines_pannes)
use_jours.shape
# Out:
# (735, 24)

# %%
machine1 = machines_utiles[0]
use_machine1 = use_jours[machine1]
use_machine1[use_machine1 > 0 ].head()
# Out:
# 2020-01-01    1
# 2020-01-02    1
# 2020-01-03    1
# 2020-01-04    1
# 2020-01-05    1
# Name: 7SXAWU81, dtype: int64

# %%
machine2 = machines_secours[0]
use_machine2 = use_jours[machine2]
use_machine2[use_machine2 == 0 ].head()
# Out:
# 2020-01-01    0
# 2020-01-02    0
# 2020-01-03    0
# 2020-01-04    0
# 2020-01-05    0
# Name: 7SXAWU98, dtype: int64

# %%
total_use_jours = use_jours.sum(axis=1)
total_use_jours.head()
# Out:
# 2020-01-01    21
# 2020-01-02    21
# 2020-01-03    21
# 2020-01-04    21
# 2020-01-05    21
# dtype: int64

# %%
total_use_jours[total_use_jours < nb_machines].head()
# Out:
# 2020-09-17    19
# 2020-09-18    19
# 2020-09-19    16
# 2020-12-01    20
# 2020-12-02    19
# dtype: int64

# %% [markdown]
# ## calcul des temps d'utilisation journaliere

# %%
duree_traitement = 4
nb_machines = len(machines_utiles)
temps = seances['Patients'] * duree_traitement
temps.name = 'use_duration'
temps = temps.to_frame()
temps.head()
# Out:
#             use_duration
# Date
# 2020-01-01            84
# 2020-01-01            84
# 2020-01-01            84
# 2020-01-01            20
# 2020-01-02            84

# %%
temps_jour1 = temps.resample('D').sum()
temps_jour1.head()
# Out:
#             use_duration
# Date
# 2020-01-01           272
# 2020-01-02           284
# 2020-01-03           288
# 2020-01-04             0
# 2020-01-05             0

# %%
temps_jour2 = pd.DataFrame(0, index=pannes.index, columns=pannes.columns)
for jour in temps_jour1.index:
    test = use_jours.loc[jour]
    machines_jour = test[test == 1].index
    machines_jour = machines_jour.to_list()
    nb_machines_jour = len(machines_jour)
    
    nb_total = temps_jour1.loc[jour, 'use_duration']
    nb_seances = nb_total // nb_machines_jour
    nb_retards = nb_total % nb_machines_jour
    if nb_machines_jour < nb_machines:
        print(jour, nb_seances, nb_retards, len(machines_jour))

    temps_jour2.loc[jour, machines_jour] = nb_seances * duree_traitement
    for i in range(nb_retards):
        machine = machines_jour[i]
        temps_jour2.loc[jour, machine] += duree_traitement

temps_jour2.shape
# Out:
# 2020-09-17 00:00:00 13 17 19
# 2020-09-18 00:00:00 13 13 19
# 2020-09-19 00:00:00 15 8 16
# 2020-12-01 00:00:00 14 4 20
# 2020-12-02 00:00:00 13 17 19
# 2021-05-04 00:00:00 14 6 19
# 2021-05-05 00:00:00 14 2 19
# 2021-05-06 00:00:00 13 5 19
# (735, 24)

# %% [markdown]
# ## calcul des temps initiaux et finaux

# %%
temps_initiaux = pd.DataFrame(0, index=pannes.index, columns=pannes.columns)
temps_finaux = pd.DataFrame(0, index=pannes.index, columns=pannes.columns)
for machine in temps_finaux.columns:
    print('\n', machine)
    t0 = 0
    t1 = 0
nb_lits.head()

# %%
nb_lits.value_counts()

# %% [markdown]
# ## calcul de la repartition des charges par machines

# %%
temps_effectif = generateurs['TF']
temps_total_effectif = temps_effectif.sum()
temps_total_effectif

# %%
repartition = temps_effectif / temps_total_effectif
repartition.name = 'use_duration'
repartition.head()

# %%
machines_rank = repartition.rank(method='first', ascending=False)
machines_rank.head()

# %%
machines = []
for date, row in temps_initial_hebdo.iterrows():
    temps_machines = repartition * row.use_duration
    machines_hebdo = temps_machines.to_frame()
    machines_hebdo['final_duration'] = repartition * row.final_duration
    # print(machines_hebdo)
    machines_hebdo['code'] = generateurs['Code']
    machines_hebdo['period'] = date
    machines_hebdo['rank'] = machines_rank
    # machines_hebdo['final_duration'] = temps_initial_hebdo.loc[date, 'final_duration']
    nb_lits_hebdo = nb_lits[date]
    machines_lits = machines_hebdo[machines_hebdo['rank'] <= nb_lits_hebdo]
    machines.append(machines_lits)
machines = pd.concat(machines)
machines.drop('rank', axis=1, inplace=True)
machines.head()

# %%
# verification des calculs
machines.groupby('period')['use_duration'].count().value_counts()

# %% [markdown]
# # Echantillonage par phases

# %%
# fix random seed
np.random.seed(0)

# %% [markdown]
# ## Echantillonage des semaines
# ces echantillons sont utilises pour la comparaison entre ordonnancement manuel et intelligent

# %%
periodes = [periode.date() for periode, _ in machines.groupby('period')]
periodes = pd.Series(periodes)
periodes

# %%
periodes_sample = periodes.sample(n=40)
# periodes_sample = periodes.loc[:1]
periodes_sample

# %% [markdown]
# ## Echantillonage des machines
# On doit:
# - garder le ratio patients/machines constant
# - controler le nombre de machines
# - faciliter la visualisation dans un diagrame de gantt

# %%
#print(machines['period'])

# %%
patients_group = []
machines_group = []
for periode in periodes_sample:
    patients_subgroup0 = patients[patients['period'].isin([periode])]
    machines_subgroup0 = machines[machines['period'].isin([periode])]
    nb_machine0 = machines_subgroup0.shape[0]
    for nb_machine1 in (4, 8, 21):
        machines_subgroup1 = machines_subgroup0.sample(n=nb_machine1)
        machines_subgroup1['instance'] = machines_subgroup1['period'].dt.strftime('w%Y-%m-%d-m') + str(nb_machine1)
        machines_group.append(machines_subgroup1)
        k = nb_machine1 / nb_machine0
        f = lambda val: int(np.ceil(val*k))
        patients_subgroup1 = patients_subgroup0.copy()
        patients_subgroup1['instance'] = patients_subgroup1['period'].dt.strftime('w%Y-%m-%d-m') + str(nb_machine1)
        patients_subgroup1['number'] = patients_subgroup1['number'].apply(f)
        patients_group.append(patients_subgroup1)

# %%
patients_sample = pd.concat(patients_group)
patients_sample.head(25)

# %%
machines_sample = pd.concat(machines_group)
machines_sample.head(25)

# %% [markdown]
# ## enregistrement des echantillons

# %%
patients_path = os.path.join(benchmarkdir, 'echantillons_patients.csv')
patients_sample.to_csv(patients_path)
patients_sample.dtypes

# %%
machines_path = os.path.join(benchmarkdir, 'echantillons_machines.csv')
machines_sample.to_csv(machines_path)
machines_sample.dtypes
