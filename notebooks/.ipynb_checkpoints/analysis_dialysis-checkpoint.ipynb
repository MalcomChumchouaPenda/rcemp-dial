# %%
# change directory
import os
rootdir = os.path.dirname(os.getcwd())
os.chdir(rootdir)

# make imports
from utils import rendering as vw

# %%
benchmarkid = 'Dialysis2021'
dbmsid = 'MySql'

# %%
ganttview = vw.GanttView(benchmarkid, dbmsid)
ganttview

# %%
f = lambda exp: f"{exp['problem_name']} {exp['model_name']}"
ganttview.plot('%b21', '%CEMP%', time_window=(0, 168), title_format=f)

# %%
# f = lambda exp: f"{exp['problem_name'][:-2].replace('_', '-')} ({exp['model_name'][:-5]})"
# f = lambda exp: '(a)' if exp['model_name'][:-5] == 'SCEMP' else '(b)'
# ganttview.plot('k1_20_3', '%CEMP%', title_format=f, time_window=(0, 1200), saveas='gantt_comparison.png')

# %%
# prod_var_names = ['Cmax', 'R', 'nR']
# statsview = vw.StatsView(benchmarkid, dbmsid)
# statsview.compare('RCEMPModel', 'SCEMPModel', prod_var_names, 
#                   instance_pattern='(\S+)_\d+', by_method=True,
#                   save_as='prod_performances.csv')

# %%
# maint_var_names = ['nTM', 'Abar']
# statsview.compare('RCEMPModel', 'SCEMPModel', maint_var_names, 
#                   instance_pattern='(\S+)_\d+', by_method=True,
#                   save_as='maint_performances.csv')

# %%
# exec_var_names = ['nC', 'Es']
# statsview.compare('RCEMPModel', 'SCEMPModel', exec_var_names, 
#                   instance_pattern='(\S+)_\d+', by_method=True,
#                   save_as='exec_performances.csv')

# %%
# var_names = prod_var_names + maint_var_names + exec_var_names
# statsview.test(var_names, problem_filter='%', save_as='test_performances.csv')

# %% [markdown]
# ## Calcul des retards reels

# %%
# import third libs for data
import datetime as dt
import numpy as np
import pandas as pd

# import config
from config import DATA_DIR

# %%
benchmarkname = 'HGD_dialysis_2018_2021'
benchmarkdir = os.path.join(DATA_DIR, 'raw', benchmarkname)
datapath = os.path.join(benchmarkdir, 'donnees_seances.csv')
seances = pd.read_csv(datapath, sep=';', index_col='Date', parse_dates=True, dayfirst=True)
seances.head()
# Out:
#             ID   Tour  Patients  Debut  Duree
# Date
# 2018-03-26   1  Tour1        21      5      5
# 2018-03-26   2  Tour2        21     10      5
# 2018-03-26   3  Tour3        21     15      5
# 2018-03-26   4  Tour4         8     20      5
# 2018-03-27   5  Tour1        21      5      5

# %%
retards = seances[seances.Tour == 'Tour4']
retards.head()
# Out:
#             ID   Tour  Patients  Debut  Duree
# Date
# 2018-03-26   4  Tour4         8     20      5
# 2018-03-27   8  Tour4         9     20      5
# 2018-03-28  12  Tour4         5     20      5
# 2018-03-29  16  Tour4         4     20      5
# 2018-03-30  20  Tour4         9     20      5

# %%
nR = retards['Patients']
R = retards['Patients'] * retards['Duree']
R.name, nR.name = 'R', 'nR'
real_stats = pd.concat([nR, R], axis=1)
real_stats.head()
# Out:
#             nR   R
# Date
# 2018-03-26   8  40
# 2018-03-27   9  45
# 2018-03-28   5  25
# 2018-03-29   4  20
# 2018-03-30   9  45

# %%
real_stats_hebdo = real_stats.resample('W').sum()
real_stats_hebdo.head()
# Out:
#             nR    R
# Date
# 2018-04-01  35  175
# 2018-04-08  32  160
# 2018-04-15  39  195
# 2018-04-22  40  200
# 2018-04-29  39  195

# %%
patients_path = os.path.join(benchmarkdir, 'echantillons_patients.csv')
patients_sample = pd.read_csv(patients_path)
patients_sample.head()
# Out:
#          Date  number  day  release_date  due_date  duration      period  \
# 0  2018-05-14      75    1             5        20         5  2018-05-20
# 1  2018-05-15      66    2             5        20         5  2018-05-20
# 2  2018-05-16      62    3             5        20         5  2018-05-20
# 3  2018-05-17      68    4             5        20         5  2018-05-20
# 4  2018-05-18      70    5             5        20         5  2018-05-20
#
#         instance
# 0  w2018-05-20-a
# 1  w2018-05-20-a
# 2  w2018-05-20-a
# 3  w2018-05-20-a
# 4  w2018-05-20-a

# %%
patients_sample.dtypes
# Out:
# Date            object
# number           int64
# day              int64
# release_date     int64
# due_date         int64
# duration         int64
# period          object
# instance        object
# dtype: object

# %%
real_stats_hebdo.shape
# Out:
# (165, 2)

# %%
patients_sample.shape
# Out:
# (476, 8)

# %%
periods = patients_sample['period']
periods = list(set(v for v in periods.to_dict().values()))
periods
# Out:
# ['2019-06-23',
#  '2020-01-05',
#  '2018-10-07',
#  '2019-09-08',
#  '2020-03-22',
#  '2019-02-17',
#  '2020-02-02',
#  '2021-03-28',
#  '2020-11-22',
#  '2020-07-26',
#  '2020-10-18',
#  '2021-01-03',
#  '2019-04-28',
#  '2019-10-27',
#  '2021-05-09',
#  '2021-02-21',
#  '2020-03-15',
#  '2018-05-20',
#  '2018-12-23',
#  '2020-09-06']

# %%
real_stats_hebdo.reset_index(inplace=True)
real_stats_hebdo.head(25)
# Out:
#     index       Date  nR    R
# 0       7 2018-05-20  28  140
# 1      27 2018-10-07  34  170
# 2      38 2018-12-23  32  160
# 3      46 2019-02-17  27  135
# 4      56 2019-04-28  42  210
# 5      64 2019-06-23  48  240
# 6      75 2019-09-08  47  235
# 7      82 2019-10-27  43  215
# 8      92 2020-01-05  33  165
# 9      96 2020-02-02  46  230
# 10    102 2020-03-15  51  255
# 11    103 2020-03-22  55  275
# 12    121 2020-07-26  12   60
# 13    127 2020-09-06  19   95
# 14    133 2020-10-18  14   70
# 15    138 2020-11-22  16   80
# 16    144 2021-01-03  31  155
# 17    151 2021-02-21  48  240
# 18    156 2021-03-28  47  235
# 19    162 2021-05-09  22  110

# %%
real_stats_hebdo = real_stats_hebdo[real_stats_hebdo['Date'].isin(periods)]
real_stats_hebdo.shape
# Out:
# (20, 3)

# %% [markdown]
# ## Collecte des stats simulees

# %%
sql = f"""select p.uid, p.name as problem_name, e.model_name, 
                s.name as var_name, s.value 
                from statistics s, problems p, experiments e
                where s.exp_id = e.uid and e.problem_id = p.uid
                and e.model_name in ('RCEMP-DIAL')
                and s.name in ('R', 'nR')
                and p.name like '%b21'
                order by p.name, s.name, s.value;"""

# %%
statsview = vw.StatsView(benchmarkid, dbmsid)
data = statsview.load_results(sql)
data.head(25)
# Out:
#                                     uid     problem_name  model_name var_name  \
# 0   pb:96144f23ecf94d4c84c641c87f90fbd4  w2018-05-20-b21  RCEMP-DIAL       nR
# 1   pb:96144f23ecf94d4c84c641c87f90fbd4  w2018-05-20-b21  RCEMP-DIAL        R
# 2   pb:e148e6a7593d40fb97d9e9069c349b1a  w2018-10-07-b21  RCEMP-DIAL       nR
# 3   pb:e148e6a7593d40fb97d9e9069c349b1a  w2018-10-07-b21  RCEMP-DIAL        R
# 4   pb:d62de5d5f54d4e298190970e0c13c7f7  w2018-12-23-b21  RCEMP-DIAL       nR
# 5   pb:d62de5d5f54d4e298190970e0c13c7f7  w2018-12-23-b21  RCEMP-DIAL        R
# 6   pb:38d464b7aa2f4f36abc322c86889f375  w2019-02-17-b21  RCEMP-DIAL       nR
# 7   pb:38d464b7aa2f4f36abc322c86889f375  w2019-02-17-b21  RCEMP-DIAL        R
# 8   pb:04160256c733441592be6052dcca41b9  w2019-04-28-b21  RCEMP-DIAL       nR
# 9   pb:04160256c733441592be6052dcca41b9  w2019-04-28-b21  RCEMP-DIAL        R
# 10  pb:8b9b1bcf82c043d880a0b7addaecb664  w2019-06-23-b21  RCEMP-DIAL       nR
# 11  pb:8b9b1bcf82c043d880a0b7addaecb664  w2019-06-23-b21  RCEMP-DIAL        R
# 12  pb:5679cd9a82bb4f35bad0d9d53c8de0ac  w2019-09-08-b21  RCEMP-DIAL       nR
# 13  pb:5679cd9a82bb4f35bad0d9d53c8de0ac  w2019-09-08-b21  RCEMP-DIAL        R
# 14  pb:65f1963d3ffe494b8f2e54e413fee8ce  w2019-10-27-b21  RCEMP-DIAL       nR
# 15  pb:65f1963d3ffe494b8f2e54e413fee8ce  w2019-10-27-b21  RCEMP-DIAL        R
# 16  pb:22d190eae8554db8884772a763615a43  w2020-01-05-b21  RCEMP-DIAL       nR
# 17  pb:22d190eae8554db8884772a763615a43  w2020-01-05-b21  RCEMP-DIAL        R
# 18  pb:a7e227c0dd264f99bb3b74dcbc652b87  w2020-02-02-b21  RCEMP-DIAL       nR
# 19  pb:a7e227c0dd264f99bb3b74dcbc652b87  w2020-02-02-b21  RCEMP-DIAL        R
# 20  pb:4bde9dd69b3d48c893f811d1e1fff023  w2020-03-15-b21  RCEMP-DIAL       nR
# 21  pb:4bde9dd69b3d48c893f811d1e1fff023  w2020-03-15-b21  RCEMP-DIAL        R
# 22  pb:e74197255da8452dbc312897ff93ce88  w2020-03-22-b21  RCEMP-DIAL       nR
# 23  pb:e74197255da8452dbc312897ff93ce88  w2020-03-22-b21  RCEMP-DIAL        R
# 24  pb:052bdd3278d1448699dc2a561a91a161  w2020-07-26-b21  RCEMP-DIAL       nR
#
#      value
# 0    59.00
# 1   344.15
# 2    74.00
# 3   490.15
# 4    65.00
# 5   454.15
# 6    62.00
# 7   385.15
# 8    87.00
# 9   609.15
# 10   88.00
# 11  641.15
# 12   92.00
# 13  670.15
# 14   89.00
# 15  593.10
# 16   74.00
# 17  539.90
# 18  101.00
# 19  820.70
# 20   91.00
# 21  628.85
# 22  117.00
# 23  965.85
# 24   39.00
